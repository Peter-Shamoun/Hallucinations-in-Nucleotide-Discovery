# %%
#!pip install biopython
from io import StringIO
from Bio import Entrez, SeqIO
import os
Entrez.email = "petershamoun80@gmail.com"

# %%
MAX_SEQ_LENGTH = 20_000  # Maximum allowed sequence length
MAX_FETCH_ATTEMPTS = 100  # Maximum number of fetch attempts before giving up

# Define search queries
queries = {
    "protein_coding": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND ("CDS"[Feature] OR "mRNA"[Feature])',
    "non_protein_coding": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND ("ncRNA"[Feature] OR "lncRNA"[Feature])',
    "enhancer": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND ("enhancer"[Title] OR "enhancer"[Gene Name])',
    "non_enhancer": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND NOT ("enhancer"[Title] OR "enhancer"[Gene Name])',
    "promoter": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND "promoter"[Title]',
    "non_promoter": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND NOT "promoter"[Title]',
    "splice_site": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND ("splice site"[Title] OR "splice junction"[Title])',
    "non_splice_site": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND NOT ("splice site"[Title] OR "splice junction"[Title])',
    "methylated": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND ("methylation"[Title] OR "CpG island"[Title])',
    "non_methylated": '("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND NOT ("methylation"[Title] OR "CpG island"[Title])'
}

# Create 'sequences' directory if it doesn't exist
output_dir = "sequences"
os.makedirs(output_dir, exist_ok=True)

# Function to fetch sequences from NCBI and ensure we get 'max_records' valid sequences
def fetch_fasta(query, filename, max_records=100):
    print(f"Searching NCBI for: {query}")
    
    valid_sequences = []
    fetched_ids = set()
    attempt = 0

    while len(valid_sequences) < max_records and attempt < MAX_FETCH_ATTEMPTS:
        attempt += 1
        remaining = max_records - len(valid_sequences)
        
        # Step 1: Search NCBI to get sequence IDs
        handle = Entrez.esearch(db="nucleotide", term=query, retmax=remaining)
        record = Entrez.read(handle)
        handle.close()

        # Get new sequence IDs, avoiding duplicates
        new_ids = [seq_id for seq_id in record["IdList"] if seq_id not in fetched_ids]
        fetched_ids.update(new_ids)

        if not new_ids:
            print(f"No new sequences found in attempt {attempt}. Retrying...")
            continue

        print(f"Fetching {len(new_ids)} sequences...")

        # Step 2: Fetch FASTA sequences
        handle = Entrez.efetch(db="nucleotide", id=new_ids, rettype="fasta", retmode="text")
        fasta_records = handle.read()
        handle.close()

        # Step 3: Filter sequences by length
        fasta_io = StringIO(fasta_records)
        for seq_record in SeqIO.parse(fasta_io, "fasta"):
            if len(seq_record.seq) <= MAX_SEQ_LENGTH:
                valid_sequences.append(seq_record)
                if len(valid_sequences) == max_records:
                    break  # Stop early if we reach the target count

        print(f"Valid sequences collected: {len(valid_sequences)} (Target: {max_records})")

    # Step 4: Save only the filtered sequences to file
    if valid_sequences:
        file_path = os.path.join(output_dir, filename)
        with open(file_path, "w") as f:
            SeqIO.write(valid_sequences, f, "fasta")
        print(f"Saved {len(valid_sequences)} sequences to {file_path}.")
    else:
        print(f"No sequences within allowed length ({MAX_SEQ_LENGTH}) for {filename}.")

# Run the function for each query
for label, query in queries.items():
    fetch_fasta(query, f"{label}.fasta")
# Out:
# Searching NCBI for: ("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND ("CDS"[Feature] OR "mRNA"[Feature])
# Fetching 100 sequences...
# Valid sequences collected: 100 (Target: 100)
# Saved 100 sequences to sequences\protein_coding.fasta.
# Searching NCBI for: ("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND 
fasta.
# Searching NCBI for: ("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND "promoter"[Title]
# Fetching 100 sequences...
# Valid sequences collected: 100 (Target: 100)
# Saved 100 sequences to sequences\promoter.fasta.
# Searching NCBI for: ("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND NOT "promoter"[Title]
# Fetching 100 sequences...
# Valid sequences collected: 100 (Target: 100)
# Saved 100 sequences to sequences\non_promoter.fasta.
# Searching NCBI for: ("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND ("splice site"[Title] OR "splice junction"[Title])
# Fetching 70 sequences...
# Valid sequences collected: 70 (Target: 100)
# No new sequences found in attempt 2. Retrying...
# No new sequences found in attempt 3. Retrying...
# No new sequences found in attempt 4. Retrying...
# No new sequences found in attempt 5. Retrying...
# No new sequences found in attempt 6. Retrying...
# No new sequences found in attempt 7. Retrying...
# No new sequences found in attempt 8. Retrying...
# No new sequences found in attempt 9. Retrying...
# No new sequences found in attempt 10. Retrying...
# No new sequences found in attempt 11. Retrying...
# No new sequences found in attempt 12. Retrying...
# No new sequences found in attempt 13. Retrying...
# No new sequences found in attempt 14. Retrying...
# No new sequences found in attempt 15. Retrying...
# No new sequences found in attempt 16. Retrying...
# No new sequences found in attempt 17. Retrying...
# No new sequences found in attempt 18. Retrying...
# No new sequences found in attempt 19. Retrying...
# No new sequences found in attempt 20. Retrying...
# No new sequences found in attempt 21. Retrying...
# No new sequences found in attempt 22. Retrying...
# No new sequences found in attempt 23. Retrying...
# No new sequences found in attempt 24. Retrying...
# No new sequences found in attempt 25. Retrying...
# No new sequences found in attempt 26. Retrying...
# No new sequences found in attempt 27. Retrying...
# No new sequences found in attempt 28. Retrying...
# No new sequences found in attempt 29. Retrying...
# No new sequences found in attempt 30. Retrying...
# No new sequences found in attempt 31. Retrying...
# No new sequences found in attempt 32. Retrying...
# No new sequences found in attempt 33. Retrying...
# No new sequences found in attempt 34. Retrying...
# No new sequences found in attempt 35. Retrying...
# No new sequences found in attempt 36. Retrying...
# No new sequences found in attempt 37. Retrying...
# No new sequences found in attempt 38. Retrying...
# No new sequences found in attempt 39. Retrying...
# No new sequences found in attempt 40. Retrying...
# No new sequences found in attempt 41. Retrying...
# No new sequences found in attempt 42. Retrying...
# No new sequences found in attempt 43. Retrying...
# No new sequences found in attempt 44. Retrying...
# No new sequences found in attempt 45. Retrying...
# No new sequences found in attempt 46. Retrying...
# No new sequences found in attempt 47. Retrying...
# No new sequences found in attempt 48. Retrying...
# No new sequences found in attempt 49. Retrying...
# No new sequences found in attempt 50. Retrying...
# No new sequences found in attempt 51. Retrying...
# No new sequences found in attempt 52. Retrying...
# No new sequences found in attempt 53. Retrying...
# No new sequences found in attempt 54. Retrying...
# No new sequences found in attempt 55. Retrying...
# No new sequences found in attempt 56. Retrying...
# No new sequences found in attempt 57. Retrying...
# No new sequences found in attempt 58. Retrying...
# No new sequences found in attempt 59. Retrying...
# No new sequences found in attempt 60. Retrying...
# No new sequences found in attempt 61. Retrying...
# No new sequences found in attempt 62. Retrying...
# No new sequences found in attempt 63. Retrying...
# No new sequences found in attempt 37. Retrying...
# No new sequences found in attempt 38. Retrying...
# No new sequences found in attempt 39. Retrying...
# No new sequences found in attempt 40. Retrying...
# No new sequences found in attempt 41. Retrying...
# No new sequences found in attempt 42. Retrying...
# No new sequences found in attempt 43. Retrying...
# No new sequences found in attempt 44. Retrying...
# No new sequences found in attempt 45. Retrying...
# No new sequences found in attempt 46. Retrying...
# No new sequences found in attempt 47. Retrying...
# No new sequences found in attempt 48. Retrying...
# No new sequences found in attempt 49. Retrying...
# No new sequences found in attempt 50. Retrying...
# No new sequences found in attempt 51. Retrying...
# No new sequences found in attempt 52. Retrying...
# No new sequences found in attempt 53. Retrying...
# No new sequences found in attempt 54. Retrying...
# No new sequences found in attempt 55. Retrying...
# No new sequences found in attempt 56. Retrying...
# No new sequences found in attempt 57. Retrying...
# No new sequences found in attempt 58. Retrying...
# No new sequences found in attempt 59. Retrying...
# No new sequences found in attempt 60. Retrying...
# No new sequences found in attempt 61. Retrying...
# No new sequences found in attempt 62. Retrying...
# No new sequences found in attempt 63. Retrying...
# No new sequences found in attempt 64. Retrying...
# No new sequences found in attempt 65. Retrying...
# No new sequences found in attempt 66. Retrying...
# No new sequences found in attempt 67. Retrying...
# No new sequences found in attempt 68. Retrying...
# No new sequences found in attempt 69. Retrying...
# No new sequences found in attempt 70. Retrying...
# No new sequences found in attempt 71. Retrying...
# No new sequences found in attempt 72. Retrying...
# No new sequences found in attempt 73. Retrying...
# No new sequences found in attempt 74. Retrying...
# No new sequences found in attempt 75. Retrying...
# No new sequences found in attempt 76. Retrying...
# No new sequences found in attempt 77. Retrying...
# No new sequences found in attempt 78. Retrying...
# No new sequences found in attempt 79. Retrying...
# No new sequences found in attempt 80. Retrying...
# No new sequences found in attempt 81. Retrying...
# No new sequences found in attempt 82. Retrying...
# No new sequences found in attempt 83. Retrying...
# No new sequences found in attempt 84. Retrying...
# No new sequences found in attempt 85. Retrying...
# No new sequences found in attempt 86. Retrying...
# No new sequences found in attempt 87. Retrying...
# No new sequences found in attempt 88. Retrying...
# No new sequences found in attempt 89. Retrying...
# No new sequences found in attempt 90. Retrying...
# No new sequences found in attempt 91. Retrying...
# No new sequences found in attempt 92. Retrying...
# No new sequences found in attempt 93. Retrying...
# No new sequences found in attempt 94. Retrying...
# No new sequences found in attempt 95. Retrying...
# No new sequences found in attempt 96. Retrying...
# No new sequences found in attempt 97. Retrying...
# No new sequences found in attempt 98. Retrying...
# No new sequences found in attempt 99. Retrying...
# No new sequences found in attempt 100. Retrying...
# Saved 70 sequences to sequences\non_splice_site.fasta.
# Searching NCBI for: ("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND ("methylation"[Title] OR "CpG island"[Title])
# Fetching 100 sequences...
# Valid sequences collected: 100 (Target: 100)
# Saved 100 sequences to sequences\methylated.fasta.
# Searching NCBI for: ("Homo sapiens"[Organism] OR "Mus musculus"[Organism]) AND NOT ("methylation"[Title] OR "CpG island"[Title])
# Fetching 100 sequences...
# Valid sequences collected: 100 (Target: 100)
# Saved 100 sequences to sequences\non_methylated.fasta.
